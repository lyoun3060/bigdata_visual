# %%
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import urllib.request
import json

client_id = "gRbRshnY7ghYnDaZPGCZ"
client_secret = "HRhKbdoShX"

encText = urllib.parse.quote("치킨")

url = "https://openapi.naver.com/v1/search/news?query=" + encText #+ '&display=' + str(100) # JSON 결과(디폴트)
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML로 가져오고 싶으면 xml을 써주자
request = urllib.request.Request(url)

request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
kyochon_des=[]
if(rescode==200):
    response_body = response.read()
    res_body = json.loads(response_body.decode('utf-8'))
    for item in res_body['items']:
        kyochon_des.append(item['description'])
    print(kyochon_des)
    
else:
    print("Error Code:" + rescode)
# Out:
# ['MD스토어 오픈 시간부터 1시간 동안 상품을 구매한 팬들 중 추첨을 통해 교촌<b>치킨</b> 교환권을 증정한다. 또한, 이날 정승용의 강원FC 통산 200경기를 기념하는 유니폼을 한정 판매한다. 사진 = 강원FC', '■ 유상부 씨 ( 티바두마리<b>치킨</b> 대표, 연세대 FCEO 18기 ) 모친상 = 14일(금), 빈소: 단국대학교병원 천안장례식장 특2호실, 발인: 16일(일) 오전8시,  장지: 풍세면 선영, ☎ 연락처 : 041-550-7474', '7월 29일 도곡동 본사에서 사업설명회&amp;시식회 진행 사진=기영이숯불두마리<b>치킨</b> <b>치킨</b> 창업 프랜차이즈 기영이숯불두마리<b>치킨</b>(이하 &apos;기영이숯불<b>치킨</b>&apos;)이 전국 가맹점을 대상으로 모범 가맹점 지원 프로모션을 진행한다고... ', '해당 이벤트는 먼투썬피자 매장에서 2만원 이상 구매 시 후라이드 <b>치킨</b>을 무료로 주는 행사로 동탄영탄점을 제외하고 전 매장에서 오는 17일부터 진행된다. 먼투썬피자는 검증된 선진 프랜차이즈 시스템, 튼튼한 11년 차... ', '교촌, 블랙·레드시크릿 볶음면 2종 출시 국민 소울 푸드, <b>치킨</b> 하면 &apos;치맥&apos;, &apos;치밥&apos;을 떠올리는 사람들이 많다. 국민들이 즐겨먹는 <b>치킨</b>인만큼 SNS에서는 <b>치킨</b> &apos;먹잘알(먹는 걸 잘 안다)&apos;들의 다양한 레시피와 조합들이 종종... ', '이번 프로모션은 외식물가 상승과 함께 여름 보양식으로 <b>치킨</b> 수요가 증가하고 있는 상황에 맞춰... 할인 쿠폰은 황금올리브<b>치킨</b>, 크런치 버터<b>치킨</b>, 갈리시오소 등 6종의 메뉴에 적용된다. 쿠폰은 7월 한달간 매주... ', '과거 같은 롯데그룹 계열사의 <b>치킨</b> 브랜드 &apos;통큰<b>치킨</b>&apos;에 착안해 철근이 돌출됐다는 의미로 &apos;통뼈캐슬&apos;이란 조롱을 받아야만 했다. 사실
# ...

# %%
from konlpy.tag import *
Hannanum =Hannanum()
kkma = Kkma()
komoran = Komoran()
okt = Okt()
import konlpy
konlpy.__version__
# Out:
# '0.6.0'

# %%
# Hannanum.nouns(kyochon_des)


result = ('')
for kyochon in kyochon_des:
    result += kyochon+ ' '

print(result)
# Out:
# MD스토어 오픈 시간부터 1시간 동안 상품을 구매한 팬들 중 추첨을 통해 교촌<b>치킨</b> 교환권을 증정한다. 또한, 이날 정승용의 강원FC 통산 200경기를 기념하는 유니폼을 한정 판매한다. 사진 = 강원FC ■ 유상부 씨 ( 티바두마리<b>치킨</b> 대표, 연세대 FCEO 18기 ) 모친상 = 14일(금), 빈소: 단국대학교병원 천안장례식장 특2호실, 발인: 16일(일) 오전8시,  장지: 풍세면 선영, ☎ 연락처 : 041-550-7474 7월 29일 도곡동 본사에서 사업설명회&amp;시식회 진행 사진=기영이숯불두마리<b>치킨</b> <b>치킨</b> 창업 프랜차이즈 기영이숯불두마리<b>치킨</b>(이하 &apos;기영이숯불<b>치킨</b>&apos;)이 전국 가맹점을 대상으로 모범 가맹점 지원 프로모션을 진행한다고...  해당 이벤트는 먼투썬피자 매장에서 2만원 이상 구매 시 후라이드 <b>치킨</b>을 무료로 주는 행사로 동탄영탄점을 제외하고 전 매장에서 오는 17일부터 진행된다. 먼투썬피자는 검증된 선진 프랜차이즈 시스템, 튼튼한 11년 차...  교촌, 블랙·레드시크릿 볶음면 2종 출시 국민 소울 푸드, <b>치킨</b> 하면 &apos;치맥&apos;, &apos;치밥&apos;을 떠올리는 사람들이 많다. 국민들이 즐겨먹는 <b>치킨</b>인만큼 SNS에서는 <b>치킨</b> &apos;먹잘알(먹는 걸 잘 안다)&apos;들의 다양한 레시피와 조합들이 종종...  이번 프로모션은 외식물가 상승과 함께 여름 보양식으로 <b>치킨</b> 수요가 증가하고 있는 상황에 맞춰... 할인 쿠폰은 황금올리브<b>치킨</b>, 크런치 버터<b>치킨</b>, 갈리시오소 등 6종의 메뉴에 적용된다. 쿠폰은 7월 한달간 매주...  과거 같은 롯데그룹 계열사의 <b>치킨</b> 브랜드 &apos;통큰<b>치킨</b>&apos;에 착안해 철근이 돌출됐다는 의미로 &apos;통뼈캐슬&apos;이란 조롱을 받아야만 했다. 사실 신축 아파트 단지의 부실시공 및 하
# ...

# %%
Hannanum.nouns(result)
# Out:
# ['스토어',
#  '오픈',
#  '시간',
#  '1시간',
#  '동안',
#  '상품',
#  '구매',
#  '들',
#  '중',
#  '추첨',
#  '>',
#  '교환권',
#  '증정',
#  '이날',
#  '정승용의',
#  '강원FC',
#  '통산',
#  '200',
#  '기',
#  '기념',
#  '유니폼',
#  '한정',
#  '판매',
#  '강원FC',
#  '■',
#  '유상부',
#  '>',
#  '대표',
#  '연세대',
#  '18기',
#  '모친상',
#  '14일(금),',
#  '빈소',
#  '단국대학교병원',
#  '천안장례식장',
#  '특2호실,',
#  '발',
#  '16일(일)',
#  '오전8시,',
#  '장지',
#  '풍세',
#  '선영',
#  '☎',
#  '연락처',
#  '041-550-7474',
#  '7월',
#  '29일',
#  '도곡동',
#  '본사',
#  '사업설명회&amp;시식회',
#  '진행',
#  '>',
#  '>',
#  '창업',
#  '프랜차이즈',
#  '>(이하',
#  '>&apos;)',
#  '전국',
#  '가맹점',
#  '대상',
#  '모범',
#  '가맹점',
#  '지원',
#  '프로모션',
#  '진행',
#  '해당',
#  '이벤트',
#  '먼투썬피',
#  '매장',
#  '2만원',
#  '이상',
#  '구매',
#  '시',
#  '후라이드',
#  '>',
#  '무료',
#  '행사',
#  '동탄영탄점',
#  '제외',
#  '전',
#  '매장',
#  '17일',
#  '진행',
#  '먼투썬피자',
#  '검증',
#  '선진',
#  '프랜차이즈',
#  '시스템',
#  '튼튼',
#  '11년',
#  '차',
#  '교촌,',
#  '블랙·레드시크릿',
#  '볶음면',
#  '2종',
#  '출시',
#  '국민',
#  '소울',
#  '푸드',
#  '>',
# ...

# %%
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
from nltk import Text
from matplotlib import font_manager, rc

# %%
font_path = 'c:/Windows/Fonts/malgun.ttf'
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

# %%
kyo_des=Text(okt.nouns(result), name='kyo_des')
kyo_des.plot(30)
plt.show()

# %%
kyochon_description=kyo_des.vocab()

# %%
from wordcloud import WordCloud


font_path = 'c:/Windows/Fonts/malgun.ttf'
wc =WordCloud(width=1000, height=800, background_color='white', font_path=font_path)
plt.imshow(wc.generate_from_frequencies(kyochon_description))
plt.axis('off')
plt.show()
